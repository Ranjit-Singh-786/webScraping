# %% [markdown]
# if you want to scrape a website
# 1. use the API
# 2. HTML web scraping using some tool like bs4

# %%
import requests as rq
import pandas as pd
from bs4 import BeautifulSoup

# %%
url="https://www.flipkart.com/search?q=mi+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=mi+mobiles%7CMobiles&requestId=467afaae-a088-4ed9-bb77-cccb4c4d2e1b&as-backfill=on"

# %%
req=rq.get(url)

# %%
req.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4a7b8.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57
# ...

# %%
<div class="_4rR01T">REDMI 10A (Slate grey, 64 GB)</div>

# %%
soup=BeautifulSoup(req.content,'html5lib')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())

# print must be apply otherwise it will show with /n
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.dd97f3.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
soup.find_all('div',{'class':'_4rR01T'})
# Out:
# [<div class="_4rR01T">REDMI 10A (Slate grey, 64 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Coral Green, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Metallic Blue, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Metallic Blue, 32 GB)</div>,
#  <div class="_4rR01T">Redmi Note 11 (Horizon Blue, 64 GB)</div>,
#  <div class="_4rR01T">Redmi Note 11 (Horizon Blue, 128 GB)</div>,
#  <div class="_4rR01T">REDMI 10A (Sea Blue, 64 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Carbon Black, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Carbon Black, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Coral Green, 32 GB)</div>,
#  <div class="_4rR01T">REDMI Note 11T 5G (Aquamarine Blue, 128 GB)</div>,
#  <div class="_4rR01T">REDMI Note 11T 5G (Matte black, 128 GB)</div>,
#  <div class="_4rR01T">Redmi Note 11 (Starburst White, 64 GB)</div>,
#  <div class="_4rR01T">Redmi 9A (Nature Green, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A (SeaBlue, 32 GB)</div>,
# ...

# %%
<div class="_3LWZlK">4.2<img src="..." class="_1wB99o"></div>

# %%
soup.find_all('div',{'class':'_3LWZlK'})

# rating
# Out:
# [<div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
# ...

# %%
len(soup.find_all('div',{'class':'_3LWZlK'}))
# Out:
# 39

# %%
rating=soup.find_all('div',{'class':'_3LWZlK'})

# %%
rating[0]
# Out:
# <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>

# %%
# code with harry

# %%
url
# Out:
# 'https://www.flipkart.com/search?q=mi+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=mi+mobiles%7CMobiles&requestId=467afaae-a088-4ed9-bb77-cccb4c4d2e1b&as-backfill=on'

# %%
r=rq.get(url)

# %%
htmlcontent = r.content

# %%
htmlcontent
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4a7b8.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57
# ...

# %%
soup=BeautifulSoup(htmlcontent,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4a7b8.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
print(soup.title)
# Out:
# <title>Mi Mobiles- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %%
title.string

# for only string
# Out:
# 'Mi Mobiles- Buy Products Online at Best Price in India - All Categories | Flipkart.com'

# %%
title=soup.title

# %%
type(title)

# object
# Out:
# bs4.element.Tag

# %%
type(title.string)

# it is special type of string which are used by beautifull

# object
# Out:
# bs4.element.NavigableString

# %%
type(soup)

# objects
# Out:
# bs4.BeautifulSoup

# %%
paras=soup.find_all('p')

# %%
anchor=soup.find_all('a')
anchor
# get all anchor tag
# Out:
# [<a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>,
#  <a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a>,
#  <a class="_1_3w1N" href="/account/login?ret=/search%3Fq%3Dmi%2Bmobiles%26sid%3Dtyy%252C4io%26as%3Don%26as-show%3Don%26otracker%3DAS_QueryStore_OrganicAutoSuggest_1_2_na_na_na%26otracker1%3DAS_QueryStore_OrganicAutoSuggest_1_2_na_na_na%26as-pos%3D1%26as-type%3DRECENT%26suggestionId%3Dmi%2Bmobiles%257CMobiles%26requestId%3D467afaae-a088-4ed9-bb77-cccb4c4d2e1b%26as-backfill%3Don">Login</a>,
#  <a class="_3-PJz-" href="https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span>Become a Seller</span></a>,
# ...

# %%
paras

# all paragraph
# Out:
# [<p class="_2-N8zT">Delightful</p>,
#  <p class="_2sc7ZR _2V5EHH">Gaurav Kumar</p>,
#  <p class="_2mcZGG" id="review-457c71af-ae31-4da4-9930-46e56289a00b"><span>Certified Buyer</span></p>,
#  <p class="_2sc7ZR">4months ago</p>,
#  <p class="_2-N8zT">Wonderful</p>,
#  <p class="_2sc7ZR _2V5EHH">Priyanshu Singh</p>,
#  <p class="_2mcZGG" id="review-7d9f5fdf-9d7e-4866-a140-3bf5ec314e82"><span>Certified Buyer</span></p>,
#  <p class="_2sc7ZR">Today</p>,
#  <p class="_2-N8zT">Classy product</p>,
#  <p class="_2sc7ZR _2V5EHH">Prachi Tripathi</p>,
#  <p class="_2mcZGG" id="review-a81f948f-d40b-4eeb-b5d1-3eb8a42c18bf"><span>Certified Buyer</span></p>,
#  <p class="_2sc7ZR">1month ago</p>,
#  <p class="_2-N8zT">Not recommended at all</p>,
#  <p class="_2sc7ZR _2V5EHH">Mirza  Baig</p>,
#  <p class="_2mcZGG" id="review-a3d84809-bf23-465b-bed5-84668555b4df"><span>Certified Buyer</span></p>,
#  <p class="_2sc7ZR">1day ago</p>,
#  <p class="_2-N8zT">Terrific purchase</p>,
# ...

# %%
class_of_paras=soup.find('p')['class']
class_of_paras

# single class of paragraph
# Out:
# ['_2-N8zT']

# %%
soup.find('p')['id']

# because there is no id , thats why i got error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [87], in <cell line: 1>()
# ----> 1 soup.find('p')['id']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\element.py:1519, in Tag.__getitem__(self, key)
#    1516 def __getitem__(self, key):
#    1517     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1518     and throws an exception if it's not there."""
# -> 1519     return self.attrs[key]
#
# KeyError: 'id'

# %%
# find all the elements with class name

soup.find_all('p',class_='_2-N8zT')
# Out:
# [<p class="_2-N8zT">Delightful</p>,
#  <p class="_2-N8zT">Wonderful</p>,
#  <p class="_2-N8zT">Classy product</p>,
#  <p class="_2-N8zT">Not recommended at all</p>,
#  <p class="_2-N8zT">Terrific purchase</p>,
#  <p class="_2-N8zT">Very poor</p>,
#  <p class="_2-N8zT">Super!</p>,
#  <p class="_2-N8zT">Hated it!</p>,
#  <p class="_2-N8zT">Super!</p>,
#  <p class="_2-N8zT">Brilliant</p>]

# %%
# get the text from the paragrapg 

soup.find('p').get_text()
# Out:
# 'Delightful'

# %%
soup.get_text()

# get the paragraph text from complete soup
# Out:
# 'Mi Mobiles- Buy Products Online at Best Price in India - All Categories | Flipkart.com      Explore PlusLoginBecome a Seller More CartFiltersCATEGORIESMobiles & AccessoriesMobilesPrice......Min₹10000₹15000₹20000₹30000to₹10000₹15000₹20000₹30000₹30000+BrandMiSPICEREDMI?Customer Ratings4★ & above3★ & aboveGST Invoice AvailableRAM4 GB3 GB2 GB6 GB8 GB and Above1GB and BelowInternal StorageBattery CapacityScreen SizePrimary CameraSecondary CameraProcessor BrandSpecialityResolution TypeOperating SystemNetwork TypeSim TypeOffersNo Cost EMISpecial PriceBuy More, Save MoreFeaturesTypeNumber of CoresAvailabilityDiscount40% or more30% or more20% or more10% or more50% or moreOperating System Version NameClock SpeedNeed help?Help me decideHomeMobiles & AccessoriesMobilesShowing 1 – 24 of 568 results for "mi mobiles"Sort ByRelevancePopularityPrice -- Low to HighPrice -- High to LowNewest FirstAdd to CompareREDMI 10A (Slate grey, 64 GB)4.11,313 Ratings\xa0&\xa095 Reviews4 GB RAM | 64 GB ROM16.59 cm
# ...

# %%
acnhor=soup.find_all('a')
for link in anchor:
    if (link!='#') :
        
        print(link.get('href'))

# link of all the anchor
# Out:
# /
# /plus
# /account/login?ret=/search%3Fq%3Dmi%2Bmobiles%26sid%3Dtyy%252C4io%26as%3Don%26as-show%3Don%26otracker%3DAS_QueryStore_OrganicAutoSuggest_1_2_na_na_na%26otracker1%3DAS_QueryStore_OrganicAutoSuggest_1_2_na_na_na%26as-pos%3D1%26as-type%3DRECENT%26suggestionId%3Dmi%2Bmobiles%257CMobiles%26requestId%3D467afaae-a088-4ed9-bb77-cccb4c4d2e1b%26as-backfill%3Don
# https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&utm_medium=websitedirect
# /viewcart?exploreMode=true&preference=FLIPKART
# /mobiles-accessories/pr?sid=tyy&q=mi+mobiles&otracker=categorytree
# /mobiles/pr?sid=tyy,4io&q=mi+mobiles&otracker=categorytree
# /buying-guide/mobiles?sid=tyy,4io&otracker=bg_from_browse_lhs
# /
# /mobiles-accessories/pr?sid=tyy&marketplace=FLIPKART
# /mobiles/pr?sid=tyy,4io&marketplace=FLIPKART
# ...

# %%
acnhor=soup.find_all('a')
all_links=set()
for link in anchor:
    if (link.get('href')!='#') :
        all_links.add(link.get('href'))

# link of all the anchor

# %%
# there is all links fetched without starting links
# there you will have to add the starting link before execute this links

print(all_links)
len(all_links)
# Out:
# {'/helpcentre?otracker=undefined_footer_footer_navlinks', '/pages/ewaste-compliance-tnc?otracker=undefined_footer_navlinks', '/redmi-note-11-pro-plus-5g-stealth-black-128-gb/p/itmd029928dc2e7e?pid=MOBGCQRR6Z8CA6PU&lid=LSTMOBGCQRR6Z8CA6PUDLZY8O&marketplace=FLIPKART&q=mi+mobiles&store=tyy%2F4io&srno=s_1_14&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&fm=organic&iid=808f0040-0e04-40f1-bf03-720d8c3632d0.MOBGCQRR6Z8CA6PU.SEARCH&ppt=None&ppn=None&ssid=pk6h9frvhc0000001660916653390&qH=fe263b216b5e362a', '/search?q=mi+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=mi+mobiles%7CMobiles&requestId=467afaae-a088-4ed9-bb77-cccb4c4d2e1b&as-backfill=on&page=4', '/about-us?otracker=undefined_footer_navlinks', '/mobiles-accessories/pr?sid=tyy&q=mi+mobiles&otracker=categorytree', '/redmi-note-11-sta
# ...

# %%
for link in all_links:
    print(link,'\n')
# Out:
# /helpcentre?otracker=undefined_footer_footer_navlinks
#
# /pages/ewaste-compliance-tnc?otracker=undefined_footer_navlinks
#
# /redmi-note-11-pro-plus-5g-stealth-black-128-gb/p/itmd029928dc2e7e?pid=MOBGCQRR6Z8CA6PU&lid=LSTMOBGCQRR6Z8CA6PUDLZY8O&marketplace=FLIPKART&q=mi+mobiles&store=tyy%2F4io&srno=s_1_14&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&fm=organic&iid=808f0040-0e04-40f1-bf03-720d8c3632d0.MOBGCQRR6Z8CA6PU.SEARCH&ppt=None&ppn=None&ssid=pk6h9frvhc0000001660916653390&qH=fe263b216b5e362a
#
# /search?q=mi+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=RECENT&suggestionId=mi+mobiles%7CMobiles&requestId=467afaae-a088-4ed9-bb77-cccb4c4d2e1b&as-backfill=on&page=4
#
# /about-us?otracker=undefined_footer_navlinks
#
# /mobiles-accessories/pr?sid=tyy&q=mi+mobiles&otracker=categorytree
#
# ...

# %% [markdown]
# # exit()  of python
# for terminate the python executiohn

# %%
markup = "<p><!-- this is comment --></p>"

# %%
soup2=BeautifulSoup(markup,'html.parser')

# %%
soup2.p
# Out:
# <p><!-- this is comment --></p>

# %%
soup2.p.string
# Out:
# ' this is comment '

# %%
type(soup2.p.string)
# Out:
# bs4.element.Comment

# %%
soup3=BeautifulSoup(markup,'html5lib')

# %%
soup3.p
# Out:
# <p><!-- this is comment --></p>

# %%
soup3.p.string
# Out:
# ' this is comment '

# %%
soup.find( class_='_3LWZlK')
# for particular class
# Out:
# <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>

# %%
soup.find( class_='_3LWZlK')
# Out:
# <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>

# %%
for clas in soup.find_all( class_='_3LWZlK'):
    print(clas,'\n')
    
# it is class of rating
# Out:
# <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>
#
# <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>
#
# ...

# %%
for cld in soup.find( class_='_3LWZlK').children:
    print(cld,'\n')
    
it has only two children first rating and second value of image
# Out:
# 4.1
#
# <img class="_1wB99o" src="..."/>

# %%
for rating in soup.find_all(class_='_3LWZlK'):
    for j in rating.children:
        print(j,'\n')
#
# Out:
# 4.1
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.1
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.3
#
# <img class="_1wB99o" src="..."/>
#
# 4.3
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.1
#
# <img class="_1wB99o" src="..."/>
#
# 4.1
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# <img class="_1wB99o" src="..."/>
#
# 4.2
#
# ...

# %%
soup.find(class_='_3LWZlK').contents
# Out:
# ['4.1',
#  <img class="_1wB99o" src="..."/>]

# %%
for rat in soup.find_all(class_='_3LWZlK'):
#     print(rat,'\n')
    for j in rat.contents:
        print(j)
# Out:
# 4.1
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.1
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.3
# <img class="_1wB99o" src="..."/>
# 4.3
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.1
# <img class="_1wB99o" src="..."/>
# 4.1
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# <img class="_1wB99o" src="..."/>
# 4.2
# ...

# %%
ratings=[]
for rat in soup.find_all(class_='_3LWZlK'):

    for i,j in enumerate(rat.contents):
        if i==0:
            ratings.append(j)   # fetched the ranks
        else:
            print(j)
# Out:
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# <img class="_1wB99o" src="..."/>
# ...

# %%
ratings
# Out:
# ['4.1',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.1',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.3',
#  '4.3',
#  '4.2',
#  '4.2',
#  '4.1',
#  '4.1',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4',
#  '5',
#  '4.1',
#  '5',
#  '1',
#  '4.2',
#  '5',
#  '1',
#  '4.2',
#  '5',
#  '1',
#  '4.2',
#  '5',
#  '5']
